# %% [markdown]
# # Model 17 — Asimetrik Ordinal Maliyet
#
# Sabit 0/1/4 maliyet matrisiyle Model 14 olasılıklarının karar katmanı değiştirilir; kilitli test kapalıdır.

# %%
import json
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
MODEL_DIR = ROOT / 'data' / 'processed' / 'model'
sonuc = json.loads((MODEL_DIR / 'model_17_asimetrik_maliyet_ozet.json').read_text(encoding='utf-8'))
sonuc['karar'], sonuc['test'], sonuc['maliyet_matrisi'], sonuc['argmax_model14_kontrol']

# %%
pd.DataFrame(sonuc['genel_metrikler']).T.sort_values('mcc', ascending=False)

# %% [markdown]
# ## Terminal yorum
#
# MCC 0,0896 ile çok az yükselirken macro-F1 0,2725'e ve accuracy %31'e düştü. Çok-metrikli kapı başarısız: **ASIMETRIK_MALIYET_TERFI_YOK**.
