# %% [markdown]
# # Model 16 — Nested Persistence–Lojistik Hibrit
#
# Dış origin ağırlıkları yalnız dış train içindeki rolling sonuçlarla seçilir; kilitli test kapalıdır.

# %%
import json
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
MODEL_DIR = ROOT / 'data' / 'processed' / 'model'
sonuc = json.loads((MODEL_DIR / 'model_16_nested_hibrit_ozet.json').read_text(encoding='utf-8'))
sonuc['karar'], sonuc['test'], sonuc['secilen_agirlik_dagilimi'], sonuc['nested_sayac']

# %%
pd.DataFrame(sonuc['genel_metrikler']).T.sort_values('mcc', ascending=False)

# %% [markdown]
# ## Terminal yorum
#
# Nested seçim sızıntısızdır fakat dış MCC=0,0031 ve macro-F1=0,3136 ile persistence'ın altına düşmüştür: **NESTED_HIBRIT_TERFI_YOK**.
