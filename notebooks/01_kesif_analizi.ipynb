# %% [markdown]
# # Keşifsel Analiz — DF-A / DF-B
#
# Serbest analiz notebook'u. Veri sözlüğü ve sütun geçmişi için `notebooks/README.md`'ye bakınız.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.width", 200)

# %%
DATA_DIR = "../data/processed/dataframes"

df_a = pd.read_csv(f"{DATA_DIR}/df_a_kapsama_testli_v2.csv")
df_b = pd.read_csv(f"{DATA_DIR}/df_b_zengin_2024_bugun_v2.csv")

print("DF-A:", df_a.shape, df_a["referans_ayi"].min(), "-", df_a["referans_ayi"].max())
print("DF-B:", df_b.shape, df_b["referans_ayi"].min(), "-", df_b["referans_ayi"].max())

# %%
df_a.head()

# %%
df_b.head()

# %%
df_a.describe()
